# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('repos.csv')
df
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_51700\3065448333.py:1: DtypeWarning: Columns (65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('repos.csv')
#                id                           node_id  \
# 0       115952610  MDEwOlJlcG9zaXRvcnkxMTU5NTI2MTA=
# 1       115914108  MDEwOlJlcG9zaXRvcnkxMTU5MTQxMDg=
# 2       115932875  MDEwOlJlcG9zaXRvcnkxMTU5MzI4NzU=
# 3       115905660  MDEwOlJlcG9zaXRvcnkxMTU5MDU2NjA=
# 4       115901925  MDEwOlJlcG9zaXRvcnkxMTU5MDE5MjU=
# ...           ...                               ...
# 121094  361324852  MDEwOlJlcG9zaXRvcnkzNjEzMjQ4NTI=
# 121095  361495043  MDEwOlJlcG9zaXRvcnkzNjE0OTUwNDM=
# 121096  361539179  MDEwOlJlcG9zaXRvcnkzNjE1MzkxNzk=
# 121097  361311005  MDEwOlJlcG9zaXRvcnkzNjEzMTEwMDU=
# 121098  361331482  MDEwOlJlcG9zaXRvcnkzNjEzMzE0ODI=
#
#                              name                        full_name  private  \
# ...

# %%
columns_to_keep = ["name", "full_name", "html_url","description","created_at","updated_at","pushed_at","stargazers_count","language","forks_count","topics","license"]
new_df = df.loc[:, columns_to_keep]

# %%
new_df
# Out:
#                              name                        full_name  \
# 0       awesome-developer-streams    bnb/awesome-developer-streams
# 1       Deep-Learning-21-Examples  hzy46/Deep-Learning-21-Examples
# 2                             lit                        ajusa/lit
# 3                  hdl_graph_slam            koide3/hdl_graph_slam
# 4                  react-projects            ajayns/react-projects
# ...                           ...                              ...
# 121094          laravel-xlswriter         Lysice/laravel-xlswriter
# 121095                     sysgen                MVS-sysgen/sysgen
# 121096                    ugbasic         spotlessmind1975/ugbasic
# 121097              midwayjs-crud      developeryvan/midwayjs-crud
# 121098            ozip_decryption          ksauraj/ozip_decryption
#
#                                                  html_url  \
# 0        https://github.com/bnb/awesome-developer-streams
# ...

# %%
# Vérifier les données manquantes
new_df.isnull().sum()
# Out:
# name                    0
# full_name               0
# html_url                0
# description          6877
# created_at              0
# updated_at              0
# pushed_at               0
# stargazers_count        0
# language            10791
# forks_count             0
# topics                  0
# license             34583
# dtype: int64

# %%
# Vérifier les données manquantes
new_df.loc[(new_df['description'].isna()) & (new_df['language'].isna()) & (new_df['license'].isna())]
# Out:
#                                          name  \
# 314                                        ss
# 722                              wenda-helper
# 796                    chinese_entity_linking
# 1390                           Rxjs5-Ultimate
# 1574                      Mechanical-datasets
# ...                                       ...
# 120552                                 issues
# 120711                          solana-season
# 120793                ComputerUsingLevelCheck
# 120991         aprenda_rails_da_maneira_facil
# 121063  detection-engineering-maturity-matrix
#
#                                              full_name  \
# 314                                   allenking1028/ss
# 722                             rrdssfgcs/wenda-helper
# 796                     lhlclhl/chinese_entity_linking
# 1390                          softchris/Rxjs5-Ultimate
# 1574                     cathysiyu/Mechanical-datasets
# ...                                                ...
# ...

# %%
# Supprimer les lignes avec des données manquantes
df1 = new_df.loc[(new_df['description'].isna()) & (new_df['language'].isna()) & (new_df['license'].isna())].index
new_df.drop(df1, inplace=True)

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
new_df.loc[new_df['license'].isna()]
# Out:
#                              name                          full_name  \
# 1       Deep-Learning-21-Examples    hzy46/Deep-Learning-21-Examples
# 4                  react-projects              ajayns/react-projects
# 8         deeplearning-assignment    Wasim37/deeplearning-assignment
# 10         Satellite-Segmentation  AstarLight/Satellite-Segmentation
# 16                    PythonBasic               daacheng/PythonBasic
# ...                           ...                                ...
# 121093            awesome-faraday         lostisland/awesome-faraday
# 121094          laravel-xlswriter           Lysice/laravel-xlswriter
# 121095                     sysgen                  MVS-sysgen/sysgen
# 121097              midwayjs-crud        developeryvan/midwayjs-crud
# 121098            ozip_decryption            ksauraj/ozip_decryption
#
#                                                  html_url  \
# 1       https://github.com/hzy46/Deep-Learning-21-Exam...
# ...

# %%
#Remplacer les valeurs NaN dans la colonne license
new_df['license'].fillna('No license' , inplace=True)

# %%
new_df.loc[new_df['license'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, full_name, html_url, description, created_at, updated_at, pushed_at, stargazers_count, language, forks_count, topics, license]
# Index: []

# %%
new_df.loc[new_df['language'].isna()]
# Out:
#                                              name  \
# 0                       awesome-developer-streams
# 23                         data-matching-software
# 36                           awesome-dev-websites
# 41                                      Megalodon
# 52                           SQL-for-Data-Science
# ...                                           ...
# 121073         aid_adventure_vulnerability_report
# 121081                                     ericpd
# 121092  awesome-python-machine-learning-resources
# 121093                            awesome-faraday
# 121098                            ozip_decryption
#
#                                                 full_name  \
# 0                           bnb/awesome-developer-streams
# 23                        J535D165/data-matching-software
# 36                   christopherkade/awesome-dev-websites
# 41                                       vyraun/Megalodon
# 52                    trentparkinson/SQL-for-Data-Science
# ...

# %%
df2 = new_df.loc[new_df['language'].isna()].index
new_df.drop(df2 , inplace = True)

# %%
new_df.loc[new_df['language'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, full_name, html_url, description, created_at, updated_at, pushed_at, stargazers_count, language, forks_count, topics, license]
# Index: []

# %%
new_df.loc[new_df['description'].isna()]
# Out:
#                                                name  \
# 10                           Satellite-Segmentation
# 25                                dynamodbguide.com
# 67                             unity-excel-importer
# 165                                  spark-aurelius
# 175     head-first-reactive-with-spring-and-reactor
# ...                                             ...
# 120996                           stealth-controller
# 121010                          todo-mvc-auth-local
# 121011                                  rocky-tools
# 121045                            ai-lyrics-writing
# 121089                                 hot-reload-c
#
#                                                 full_name  \
# 10                      AstarLight/Satellite-Segmentation
# 25                           alexdebrie/dynamodbguide.com
# 67                            mikito/unity-excel-importer
# 165                                laravel/spark-aurelius
# ...

# %%
#Remplacer les valeurs NaN dans la colonne description
new_df['description'].fillna('No description' , inplace = True)

# %%
new_df.loc[new_df['description'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, full_name, html_url, description, created_at, updated_at, pushed_at, stargazers_count, language, forks_count, topics, license]
# Index: []

# %%
import pandas as pd
import re

# fonction pour filtrer les emojis
def remove_emoji(text):
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# appliquer la fonction remove_emoji à la colonne 'description'
new_df['description'] = new_df['description'].astype(str).apply(remove_emoji)

# %%
new_df
# Out:
#                              name                        full_name  \
# 1       Deep-Learning-21-Examples  hzy46/Deep-Learning-21-Examples
# 2                             lit                        ajusa/lit
# 3                  hdl_graph_slam            koide3/hdl_graph_slam
# 4                  react-projects            ajayns/react-projects
# 5                          weixin               game-helper/weixin
# ...                           ...                              ...
# 121091          gamescope-session      ChimeraOS/gamescope-session
# 121094          laravel-xlswriter         Lysice/laravel-xlswriter
# 121095                     sysgen                MVS-sysgen/sysgen
# 121096                    ugbasic         spotlessmind1975/ugbasic
# 121097              midwayjs-crud      developeryvan/midwayjs-crud
#
#                                                  html_url  \
# 1       https://github.com/hzy46/Deep-Learning-21-Exam...
# ...

# %%
new_df.head()
# Out:
#                         name                        full_name  \
# 1  Deep-Learning-21-Examples  hzy46/Deep-Learning-21-Examples
# 2                        lit                        ajusa/lit
# 3             hdl_graph_slam            koide3/hdl_graph_slam
# 4             react-projects            ajayns/react-projects
# 5                     weixin               game-helper/weixin
#
#                                             html_url  \
# 1  https://github.com/hzy46/Deep-Learning-21-Exam...
# 2                       https://github.com/ajusa/lit
# 3           https://github.com/koide3/hdl_graph_slam
# 4           https://github.com/ajayns/react-projects
# 5              https://github.com/game-helper/weixin
#
#                                          description            created_at  \
# 1                                    21———TensorFlow  2018-01-01T11:07:50Z
# 2  World's smallest responsive  css framework (39...  2018-01-01T17:00:44Z
# ...

# %%
new_df.reset_index(inplace = True)

# %%
type(new_df['topics'][0])
# Out:
# str

# %%
new_df['topics'] = new_df['topics'].apply(lambda x: eval(x))

# %%
type(new_df['topics'][0])
# Out:
# list

# %%
len(new_df['topics'][1])
# Out:
# 5

# %%
print(new_df[['name', 'language']])
# Out:
#                              name    language
# 0       Deep-Learning-21-Examples      Python
# 1                             lit         CSS
# 2                  hdl_graph_slam         C++
# 3                  react-projects  JavaScript
# 4                          weixin  JavaScript
# ...                           ...         ...
# 110303          gamescope-session       Shell
# 110304          laravel-xlswriter         PHP
# 110305                     sysgen         JCL
# 110306                    ugbasic           C
# 110307              midwayjs-crud  TypeScript
#
# [110308 rows x 2 columns]

# %%
for i in range(len(new_df)):
    if len(new_df['topics'][i]) == 0:
        #print(new_df['name'][i])
        new_df['topics'][i] = [new_df['name'][i], new_df['language'][i]]
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_51700\1922280024.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['topics'][i] = [new_df['name'][i], new_df['language'][i]]

# %%
empty_topics = new_df.loc[new_df['topics'].apply(len) == 0 , ['name', 'full_name','topics']]
print(empty_topics)
# Out:
#                              name                          full_name topics
# 0       Deep-Learning-21-Examples    hzy46/Deep-Learning-21-Examples     []
# 9          Satellite-Segmentation  AstarLight/Satellite-Segmentation     []
# 13                      iOSREBook              AloneMonkey/iOSREBook     []
# 15                    PythonBasic               daacheng/PythonBasic     []
# 18       facenet-face-recognition   Skuldur/facenet-face-recognition     []
# ...                           ...                                ...    ...
# 110301               hot-reload-c                cj1128/hot-reload-c     []
# 110302            obsidian-bridge            aidenlx/obsidian-bridge     []
# 110303          gamescope-session        ChimeraOS/gamescope-session     []
# 110305                     sysgen                  MVS-sysgen/sysgen     []
# 110306                    ugbasic           spotlessmind1975/ugbasic     []
#
# [45244 rows x 3 columns]

# %%
new_df
# Out:
#          index                       name                        full_name  \
# 0            1  Deep-Learning-21-Examples  hzy46/Deep-Learning-21-Examples
# 1            2                        lit                        ajusa/lit
# 2            3             hdl_graph_slam            koide3/hdl_graph_slam
# 3            4             react-projects            ajayns/react-projects
# 4            5                     weixin               game-helper/weixin
# ...        ...                        ...                              ...
# 110303  121091          gamescope-session      ChimeraOS/gamescope-session
# 110304  121094          laravel-xlswriter         Lysice/laravel-xlswriter
# 110305  121095                     sysgen                MVS-sysgen/sysgen
# 110306  121096                    ugbasic         spotlessmind1975/ugbasic
# 110307  121097              midwayjs-crud      developeryvan/midwayjs-crud
#
#                                                  html_url  \
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110308 entries, 0 to 110307
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             110308 non-null  int64
#  1   name              110308 non-null  object
#  2   full_name         110308 non-null  object
#  3   html_url          110308 non-null  object
#  4   description       110308 non-null  object
#  5   created_at        110308 non-null  object
#  6   updated_at        110308 non-null  object
#  7   pushed_at         110308 non-null  object
#  8   stargazers_count  110308 non-null  int64
#  9   language          110308 non-null  object
#  10  forks_count       110308 non-null  int64
#  11  topics            110308 non-null  object
#  12  license           110308 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 10.9+ MB

# %%
new_df['created_at'] = pd.to_datetime(new_df['created_at'])
new_df['updated_at'] = pd.to_datetime(new_df['updated_at'])
new_df['pushed_at'] = pd.to_datetime(new_df['pushed_at'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110308 entries, 0 to 110307
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             110308 non-null  int64
#  1   name              110308 non-null  object
#  2   full_name         110308 non-null  object
#  3   html_url          110308 non-null  object
#  4   description       110308 non-null  object
#  5   created_at        110308 non-null  datetime64[ns, UTC]
#  6   updated_at        110308 non-null  datetime64[ns, UTC]
#  7   pushed_at         110308 non-null  datetime64[ns, UTC]
#  8   stargazers_count  110308 non-null  int64
#  9   language          110308 non-null  object
#  10  forks_count       110308 non-null  int64
#  11  topics            110308 non-null  object
#  12  license           110308 non-null  object
# dtypes: datetime64[ns, UTC](3), int64(3), object(7)
# memory usage: 10.9+ MB

# %%
new_df
# Out:
#          index                       name                        full_name  \
# 0            1  Deep-Learning-21-Examples  hzy46/Deep-Learning-21-Examples
# 1            2                        lit                        ajusa/lit
# 2            3             hdl_graph_slam            koide3/hdl_graph_slam
# 3            4             react-projects            ajayns/react-projects
# 4            5                     weixin               game-helper/weixin
# ...        ...                        ...                              ...
# 110303  121091          gamescope-session      ChimeraOS/gamescope-session
# 110304  121094          laravel-xlswriter         Lysice/laravel-xlswriter
# 110305  121095                     sysgen                MVS-sysgen/sysgen
# 110306  121096                    ugbasic         spotlessmind1975/ugbasic
# 110307  121097              midwayjs-crud      developeryvan/midwayjs-crud
#
#                                                  html_url  \
# ...

# %%
sns.boxplot(new_df[['stargazers_count','forks_count']])
# Out:
# <Axes: >

# %%
Q1=new_df['stargazers_count'].quantile(0.25)
Q3=new_df['stargazers_count'].quantile(0.75)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)
# Out:
# 120.0
# 390.0
# 270.0

# %%
Lower_lim = Q1 - 1.5 * IQR
Upper_lim = Q3 + 1.5 * IQR

# %%
Upper_lim
# Out:
# 795.0

# %%
Lower_lim
# Out:
# -285.0

# %%
Q1=new_df['forks_count'].quantile(0.25)
Q3=new_df['forks_count'].quantile(0.75)
IQR=Q3-Q1
print(Q1)
print(Q3)
print(IQR)
# Out:
# 20.0
# 89.0
# 69.0

# %%
Lower_lim = Q1 - 1.5 * IQR
Upper_lim = Q3 + 1.5 * IQR

# %%
Upper_lim
# Out:
# 192.5

# %%
Lower_lim
# Out:
# -83.5
